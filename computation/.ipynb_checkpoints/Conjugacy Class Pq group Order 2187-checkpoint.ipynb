# %%
def get_gap_group(n, i):
    return PermutationGroup(gap_group = gap.Image(gap.IsomorphismPermGroup(gap.SmallGroup(n, i)))).as_finitely_presented_group()

# %%
def list_gap_groups(n):
    for i, H in enumerate(gap.AllSmallGroups(n)):
        print(i + 1, H.StructureDescription())

# %%
def generate_power_maps_gap(G, power_range):
    return [G.CharacterTable().PowerMap(n) for n in power_range]

# %%
# power_maps is a list of power-maps for n from 0 to N-1 (as in GAP power maps)
def generate_relations(power_maps):
    relations = []
    
    for n, pm in enumerate(power_maps):
        for xpre, y in enumerate(pm):
            x = xpre + 1
            rel = [x] * n + [-y]
            relations.append(rel)
            
    return relations

# %%
def create_group_from_relations(N, relations):
    FG = FreeGroup(N)
    # Find better method to create free abelian group...
    ab_relations = [[x, y, -x, -y] for x in range(1, N + 1) for y in range(1, N + 1)]
    total_relations = ab_relations + relations
    FGR = FG / (total_relations)
    FGS = FGR.simplified()
    return FGS

# %%
def compute_gr_cc_pq(G, power_range = None):
    Ggap = G
    if power_range == None:
        power_range = range(0, Ggap.Order().sage())
    power_maps = generate_power_maps_gap(Ggap, power_range)
    print("Power maps generated")
    N = len(power_maps[0])
    relations = generate_relations(power_maps)
    print("Relations generated")
    return create_group_from_relations(N, relations)

# %%
list_gap_groups(16)
# Out:
# 1 C16
# 2 C4 x C4
# 3 (C4 x C2) : C2
# 4 C4 : C4
# 5 C8 x C2
# 6 C8 : C2
# 7 D16
# 8 QD16
# 9 Q16
# 10 C4 x C2 x C2
# 11 C2 x D8
# 12 C2 x Q8
# 13 (C4 x C2) : C2
# 14 C2 x C2 x C2 x C2

# %%
G = get_gap_group(2187, 6479)

# %%
#G.structure_description()

# %%
X = G / G.gap().DerivedSubgroup()

# %%
X.StructureDescription()
# Out:
# "C3 x C3 x C3 x C3"

# %%
#H = compute_gr_cc_pq(G); H

# %%
#H.structure_description()

# %%
# Discovered the hard way: code assumes power_range has power n at index n.

# %%
def generate_ab_info_about_group(G, power_range = None):
    X = G / G.DerivedSubgroup()
    print("Abelianization: ", X.StructureDescription())
    H = compute_gr_cc_pq(G, power_range = power_range)
    return H
    #print("Gr of Ab: ", H.structure_description())

# %%
generate_ab_info_about_group(gap.SmallGroup(64, 13))
# Out:
# Abelianization:  C4 x C2
# Power maps generated
# Relations generated
# Finitely presented group < x1, x2, x3, x7, x10, x11, x12 | x12^2, x10^2, x11^2, x2^2, x3^2, x10*x7^-1*x10*x7, x1^4, x7^4, x1^-1*x10*x1*x10, x11*x7^-1*x11*x7, (x12*x2)^2, (x3*x2)^2, x3*x1^-1*x3*x1, (x11*x10)^2, (x11*x2)^2, x2*x1*x2*x1^-1, x2*x7^-1*x2*x7, x12*x7*x12*x7^-1, x1^-1*x7*x1*x7^-1, x3*x7*x3*x7^-1, x12*x1^-1*x12*x1, (x11*x12)^2, x11*x1*x11*x1^-1, (x3*x12)^2, (x3*x10)^2, (x12*x10)^2, (x2*x10)^2, (x3*x11)^2 >

# %%
get_gap_group(64, 13).structure_description()
# Out:
# '(C2 x C2) . ((C4 x C2) : C2) = (C4 x C2) . (C4 x C2)'

# %%
gap.SmallGroup(64, 13).Order()
# Out:
# 64

# %%
# Tests for important groups:

# %%
# Group 1:

# %%
H1 = generate_ab_info_about_group(gap.SmallGroup(2187, 6479), power_range = [0, 1, 2, 3])
# Out:
# Abelianization:  C3 x C3 x C3 x C3
# Power maps generated
# Relations generated

# %%
H2 = generate_ab_info_about_group(gap.SmallGroup(2187, 6576), power_range = [0, 1, 2, 3])
# Out:
# Abelianization:  C3 x C3 x C3 x C3
# Power maps generated
# Relations generated

# %%
# Group 2:

# %%
H3 = generate_ab_info_about_group(gap.SmallGroup(2187, 6477), power_range = [0, 1, 2, 3])
# Out:
# Abelianization:  C3 x C3 x C3 x C3
# Power maps generated
# Relations generated

# %%
H4 = generate_ab_info_about_group(gap.SmallGroup(2187, 9108), power_range = [0, 1, 2, 3])
# Out:
# Abelianization:  C3 x C3 x C3 x C3 x C3
# Power maps generated
# Relations generated

# %%
H1
# Out:
# Finitely presented group < x1, x3, x4, x5, x9, x10, x11, x12, x13, x14, x15, x16, x17, x27, x28, x29, x33, x34, x35, x36, x37, x38, x39, x40, x41, x51, x52, x53, x54, x55, x56, x57, x58, x59, x69, x70, x71, x72, x73, x74, x75, x76, x77, x78, x79, x80, x81, x82, x83, x84, x85, x86, x87, x88, x89, x90, x91, x92, x93, x94, x95, x96, x97, x98, x99, x100, x101, x102, x103, x104, x105, x106, x107, x108, x109, x110, x111, x112, x113, x114, x115, x116, x117, x118, x119 | x80^3, x79^3, x93^3, x95^3, x94^3, x99^3, x101^3, x100^3, x96^3, x98^3, x97^3, x84^3, x86^3, x85^3, x90^3, x92^3, x91^3, x87^3, x89^3, x88^3, x111^3, x113^3, x112^3, x117^3, x119^3, x118^3, x114^3, x116^3, x115^3, x102^3, x104^3, x103^3, x108^3, x110^3, x109^3, x105^3, x107^3, x106^3, x81^3, x83^3, x33^3, x78^3, x35^3, x36^3, x37^3, x70^3, x75^3, x27^3, x28^3, x29^3, x3^3, x4^3, x73^3, x59^3, x34^3, x74^3, x9^3, x10^3, x38^3, x69^3, x71^3, x1^3, x82^3, x16^3, x17^3, x5^3, x72^3, x11^3, x57^3, x13^3, x14^3, x15^3, x12^3, x56^3, x58^3, x40^3, x55^3, x51^3, x39^3, x52^3, x77^3, x76^3, x41^3, x54^3, x53^3, x1^-1*x79*x1*x79^-1, x38*x81^-1*x38^-1*x81, x1^-1*x59^-1*x1*x59, x1^-1*x52^-1*x1*x52, x89*x97^-1*x89^-1*x97, x115*x56^-1*x115^-1*x56, x28^-1*x37*x28*x37^-1, x38*x98^-1*x38^-1*x98, x76*x108^-1*x76^-1*x108, x105^-1*x116*x105*x116^-1, x38*x111^-1*x38^-1*x111, x89*x101^-1*x89^-1*x101, x89*x94^-1*x89^-1*x94, x72*x75^-1*x72^-1*x75, x89*x98^-1*x89^-1*x98, x39^-1*x54*x39*x54^-1, x89*x100^-1*x89^-1*x100, x115*x58^-1*x115^-1*x58, x38*x88^-1*x38^-1*x88, x38*x110^-1*x38^-1*x110, x38*x109^-1*x38^-1*x109, x38*x73^-1*x38^-1*x73, x38*x107^-1*x38^-1*x107, x38*x83^-1*x38^-1*x83, x115*x77^-1*x115^-1*x77, x39^-1*x55*x39*x55^-1, x13*x15^-1*x13^-1*x15, x89*x80^-1*x89^-1*x80, x115*x57^-1*x115^-1*x57, x115*x59^-1*x115^-1*x59, x38*x103^-1*x38^-1*x103, x38*x108^-1*x38^-1*x108, x28^-1*x111*x28*x111^-1, x89*x72^-1*x89^-1*x72, x13*x1^-1*x13^-1*x1, x115*x93^-1*x115^-1*x93, x115*x95^-1*x115^-1*x95, x115*x94^-1*x115^-1*x94, x115*x99^-1*x115^-1*x99, x89*x82^-1*x89^-1*x82, x115*x100^-1*x115^-1*x100, x115*x96^-1*x115^-1*x96, x115*x98^-1*x115^-1*x98, x115*x97^-1*x115^-1*x97, x115*x84^-1*x115^-1*x84, x115*x86^-1*x115^-1*x86, x115*x85^-1*x115^-1*x85, x115*x90^-1*x115^-1*x90, x115*x92^-1*x115^-1*x92, x51*x114^-1*x51^-1*x114, x51*x116^-1*x51^-1*x116, x115*x88^-1*x115^-1*x88, x40^-1*x117*x40*x117^-1, x73^-1*x116*x73*x116^-1, x51^-1*x83*x51*x83^-1, x51^-1*x84*x51*x84^-1, x40^-1*x71^-1*x40*x71, x9*x51^-1*x9^-1*x51, x96*x74^-1*x96^-1*x74, x115*x118^-1*x115^-1*x118, x96*x81^-1*x96^-1*x81, x96*x83^-1*x96^-1*x83, x96*x82^-1*x96^-1*x82, x96*x80^-1*x96^-1*x80, x115*x103^-1*x115^-1*x103, x96*x79^-1*x96^-1*x79, x73^-1*x81^-1*x73*x81, x73^-1*x83^-1*x73*x83, x96*x94^-1*x96^-1*x94, x96*x99^-1*x96^-1*x99, x39*x41^-1*x39^-1*x41, x96*x100^-1*x96^-1*x100, x13*x69^-1*x13^-1*x69, x96*x98^-1*x96^-1*x98, x96*x97^-1*x96^-1*x97, x96*x84^-1*x96^-1*x84, x96*x86^-1*x96^-1*x86, x96*x85^-1*x96^-1*x85, x96*x90^-1*x96^-1*x90, x96*x92^-1*x96^-1*x92, x96*x91^-1*x96^-1*x91, x96*x87^-1*x96^-1*x87, x77*x69^-1*x77^-1*x69, x77*x71^-1*x77^-1*x71, x39*x51^-1*x39^-1*x51, x11^-1*x113*x11*x113^-1, x11^-1*x115*x11*x115^-1, x11^-1*x112^-1*x11*x112, x11^-1*x99*x11*x99^-1, x11^-1*x114*x11*x114^-1, x11^-1*x97*x11*x97^-1, x11^-1*x96^-1*x11*x96, x11^-1*x88^-1*x11*x88, x13*x96^-1*x13^-1*x96, x11^-1*x100^-1*x11*x100, x10^-1*x27*x10*x27^-1, x11^-1*x117^-1*x11*x117, x11^-1*x93^-1*x11*x93, x11^-1*x71^-1*x11*x71, x11^-1*x95^-1*x11*x95, x11^-1*x98*x11*x98^-1, x11^-1*x111^-1*x11*x111, x11^-1*x101^-1*x11*x101, x10^-1*x17^-1*x10*x17, x10^-1*x16^-1*x10*x16, x77*x97^-1*x77^-1*x97, x11^-1*x119^-1*x11*x119, x11^-1*x118^-1*x11*x118, x10^-1*x40*x10*x40^-1, x10^-1*x12^-1*x10*x12, x10^-1*x29*x10*x29^-1, x11^-1*x79^-1*x11*x79, x10^-1*x34^-1*x10*x34, x11^-1*x94^-1*x11*x94, x11^-1*x89^-1*x11*x89, x10^-1*x15^-1*x10*x15, x10^-1*x36^-1*x10*x36, x10^-1*x38^-1*x10*x38, x10^-1*x37^-1*x10*x37, x10^-1*x14^-1*x10*x14, x10^-1*x13^-1*x10*x13, x11^-1*x116*x11*x116^-1, x77*x116^-1*x77^-1*x11 ...

# %%
H1a = H1.abelian_invariants(); (len(H1a), all(i == 3 for i in H1a))
# Out:
# (85, True)

# %%
H2a = H2.abelian_invariants(); (len(H2a), all(i == 3 for i in H2a))
# Out:
# (85, True)

# %%
H1.is_isomorphic(H2)
# Out:
# ---------------------------------------------------------------------------
# GAPError                                  Traceback (most recent call last)
# <ipython-input-86-e2d8a12a4b7b> in <module>()
# ----> 1 H1.is_isomorphic(H2)
#
# /home/torstein/TV/sage-9.0/local/lib/python3.7/site-packages/sage/groups/libgap_mixin.py in is_isomorphic(self, H)
#     611             (False, False, False)
#     612         """
# --> 613         iso = self.gap().IsomorphismGroups(H.gap())
#     614         if iso.is_bool():   # fail means not isomorphic
#     615             try:
#
# /home/torstein/TV/sage-9.0/local/lib/python3.7/site-packages/sage/libs/gap/element.pyx in sage.libs.gap.element.GapElement_MethodProxy.__call__ (build/cythonized/sage/libs/gap/element.c:20291)()
#    2664         """
#    2665         if len(args) > 0:
# -> 2666             return GapElement_Function.__call__(self, * ([self.first_argument] + list(args)))
#    2667         else:
#    2668             return GapElement_Function.__call__(self, self.first_argument)
#
# /home/torstein/TV/sage-9.0/local/lib/python3.7/site-packages/sage/libs/gap/element.pyx in sage.libs.gap.element.GapElement_Function.__call__ (build/cythonized/sage/libs/gap/element.c:19304)()
#    2512         try:
#    2513             sig_GAP_Enter()
# -> 2514             sig_on()
#    2515             if n == 0:
#    2516                 result = CALL_0ARGS(self.value)
#
# GAPError: Error, reached the pre-set memory limit
# (change it with the -o command line option)

# %%
H3a = H3.abelian_invariants(); (len(H3a), all(i == 3 for i in H3a))
# Out:
# (157, True)

# %%
H4a = H4.abelian_invariants(); (len(H4a), all(i == 3 for i in H4a))
# Out:
# (157, True)

# %%
H1.structure_description()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-66-4de2df9e5cad> in <module>()
# ----> 1 H1.structure_description()
#
# /home/torstein/TV/sage-9.0/local/lib/python3.7/site-packages/sage/groups/generic.py in structure_description(G, latex)
#    1421         return "%sD%d" % (match.group(1), int(match.group(2)) // 2)
#    1422
# -> 1423     description = str(G._gap_().StructureDescription())
#    1424
#    1425     description = re.sub(r"(\A|\W)D(\d+)", correct_dihedral_degree, description)
#
# /home/torstein/TV/sage-9.0/local/lib/python3.7/site-packages/sage/libs/gap/element.pyx in sage.libs.gap.element.GapElement_MethodProxy.__call__ (build/cythonized/sage/libs/gap/element.c:20359)()
#    2666             return GapElement_Function.__call__(self, * ([self.first_argument] + list(args)))
#    2667         else:
# -> 2668             return GapElement_Function.__call__(self, self.first_argument)
#    2669
#    2670
#
# /home/torstein/TV/sage-9.0/local/lib/python3.7/site-packages/sage/libs/gap/element.pyx in sage.libs.gap.element.GapElement_Function.__call__ (build/cythonized/sage/libs/gap/element.c:19304)()
#    2512         try:
#    2513             sig_GAP_Enter()
# -> 2514             sig_on()
#    2515             if n == 0:
#    2516                 result = CALL_0ARGS(self.value)
#
# KeyboardInterrupt:

# %%
H2.structure_description()
# Out:
# '1'

# %%
H3.structure_description()
# Out:
# '1'

# %%
H4.structure_description()
# Out:
# '1'
