# %%
M = gap.SmallGroup(2187, 6479).MultiplicationTable()

# %%
Ms = M.sage()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/torstein/TV/sage-9.0/local/lib/python3.7/site-packages/sage/interfaces/interface.py in _repr_(self)
#    1193         try:
# -> 1194             if self._get_using_file:
#    1195                 return P.get_using_file(self._name).rstrip()
#
# /home/torstein/TV/sage-9.0/local/lib/python3.7/site-packages/sage/interfaces/interface.py in __getattr__(self, attrname)
#    1204         if attrname[:1] == "_":
# -> 1205             raise AttributeError
#    1206         return P._function_element_class()(self, attrname)
#
# AttributeError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# ...

# %%
import pickle

# %%
pickle.dump(Ms, open("SG_2187_6479_mt.p", "wb"))
